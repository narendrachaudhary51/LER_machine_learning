                [1.2, 40, 0.8, 10, 10, 16.33, 31.22, 1.16, 1.17],
                [1.2, 40, 0.8, 10, 100, 26.11, 42.50, 1.16, 1.16],
                [1.6, 30, 0.5, 15, 2, 10.21, 25.30, 1.52, 1.48],
                [1.6, 30, 0.5, 15, 5, 13.58, 27.74, 1.52, 1.52],
                [1.6, 30, 0.5, 15, 10, 16.35, 30.22, 1.52, 1.52],
                [1.6, 30, 0.5, 15, 100, 26.17, 42.60, 1.52, 1.52]]

array_1 = np.array(Table_list_1)
array_2 = np.array(Table_list_2)
array_3 = np.array(Table_list_3)

# %%
plt.figure(figsize = (10,6))
plt.plot(array_1[:,4], '-o', label = 'Noisy image')
plt.plot(array_1[:,5], '-o', label = 'LineNet1 denoised image')
plt.plot(array_1[:,6], '-o', label = 'SEMNet denoised image')
plt.xlabel('Image number', fontsize = 16)
plt.ylabel('PSNR (dB)', fontsize = 16)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=14)
plt.show()

# %%
plt.figure(figsize = (10,6))
plt.plot(array_3[:,5], '-o', label = 'Noisy image')
plt.plot(array_3[:,6], '-o', label = 'LineNet2 denoised image')
plt.xlabel('Image number', fontsize = 16)
plt.ylabel('PSNR (dB)', fontsize = 16)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=14)
plt.show()

# %%
plt.figure(figsize = (10,6))
plt.plot(array_2[:,10], '-o', label = 'True LWR')
plt.plot(array_2[:,11], '-o', label = 'LineNet1 LWR')
plt.plot(array_2[:,12], '-o', label = 'EDGENet LWR')
plt.xlabel('Image number', fontsize = 16)
plt.ylabel('LWR (nm)', fontsize = 16)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=14)
plt.ylim(0.8,2.5)
plt.show()

plt.figure(figsize = (10,6))
plt.plot(array_3[:,7], '-o', label = 'True LER')
plt.plot(array_3[:,8], '-o', label = 'LineNet2 LER')
#plt.plot(array_2[:,12], '-o', label = 'EDGENet LWR')
plt.xlabel('Image number', fontsize = 16)
plt.ylabel('Mean LER (nm)', fontsize = 16)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=14)
plt.ylim(0.6,2.3)
plt.show()

# %%
## EMLC 2019 paper table
#LineNet Table
## image, Gaussian noise = 0.05, True LWR, Predicted LWR, Left Spectra distance, Right Spectra distance
Table_list_6layer = [[0.8, 10, 0.3, 2, 0.05, 1.06, float('NaN'), float('NaN'), float('NaN')],
                     [0.8, 10, 0.3, 4, 0.05, 1.06, 1.21, 298.8, 1701.1],
                     [0.8, 10, 0.3, 10, 0.05, 1.06, 1.04, 288.6, 62.2],
                     [0.8, 10, 0.3, 100, 0.05, 1.06, 1.06, 13.2, 18.6],
                     [1.2, 40, 0.7, 2, 0.05, 1.41, float('NaN'), float('NaN'), float('NaN')],
                     [1.2, 40, 0.7, 4, 0.05, 1.41, 2.22, 25.4, 568.8],
                     [1.2, 40, 0.7, 10, 0.05, 1.41, 1.42, 14.3, 11.6],
                     [1.2, 40, 0.7, 100, 0.05, 1.41, 1.41, 10.4, 7.1],
                     [1.0, 30, 0.5, 2, 0.05, 1.28, float('NaN'), float('NaN'), float('NaN')],
                     [1.0, 30, 0.5, 4, 0.05, 1.28, 1.38, 27.4, 94.4],
                     [1.0, 30, 0.5, 10, 0.05, 1.28, 1.26, 10.8, 21.5],
                     [1.0, 30, 0.5, 100, 0.05, 1.28, 1.28, 5.9, 7.1]]

Table_list_11layer = [[0.8, 10, 0.3, 2, 0.05, 1.06, 0.99, 383.5, 306.4],
                      [0.8, 10, 0.3, 4, 0.05, 1.06, 1.01, 38.3, 226.3],
                      [0.8, 10, 0.3, 10, 0.05, 1.06, 1.05, 207.7, 120.7 ],
                      [0.8, 10, 0.3, 100, 0.05, 1.06, 1.06, 17.4, 24.9],
                      [1.2, 40, 0.7, 2, 0.05, 1.41, 1.65, 38.9, 253.2],
                      [1.2, 40, 0.7, 4, 0.05, 1.41, 1.45, 18.7, 30.8],
                      [1.2, 40, 0.7, 10, 0.05, 1.41, 1.42, 18.0, 10.5],
                      [1.2, 40, 0.7, 100, 0.05, 1.41, 1.41, 10.4, 7.5],
                      [1.0, 30, 0.5, 2, 0.05, 1.28, 1.26, 48.6, 48.9],
                      [1.0, 30, 0.5, 4, 0.05, 1.28, 1.27, 14.5, 28.2],
                      [1.0, 30, 0.5, 10, 0.05, 1.28, 1.27, 10.3, 16.3],
                      [1.0, 30, 0.5, 100, 0.05, 1.28, 1.28, 6.1, 7.1]]

Table_list_17layer = [[0.8, 10, 0.3, 2, 0.05, 1.06, 0.91, 261.9, 106.4],
                      [0.8, 10, 0.3, 4, 0.05, 1.06, 0.98, 47.7, 69.5],
                      [0.8, 10, 0.3, 10, 0.05, 1.06, 1.04, 102.4, 420.1],
                      [0.8, 10, 0.3, 100, 0.05, 1.06, 1.06, 22.8, 11.3],
                      [1.2, 40, 0.7, 2, 0.05, 1.41, 1.41, 38.9, 38.1],
                      [1.2, 40, 0.7, 4, 0.05, 1.41, 1.41, 16.6, 21.8],
                      [1.2, 40, 0.7, 10, 0.05, 1.41, 1.41, 19.7, 16.7],
                      [1.2, 40, 0.7, 100, 0.05, 1.41, 1.41, 10.4, 7.1],
                      [1.0, 30, 0.5, 2, 0.05, 1.28, 1.23, 45.0, 35.6],
                      [1.0, 30, 0.5, 4, 0.05, 1.28, 1.25, 15.4, 19.5],
                      [1.0, 30, 0.5, 10, 0.05, 1.28, 1.25, 12.4, 14.5],
                      [1.0, 30, 0.5, 100, 0.05, 1.28, 1.28, 5.9, 6.4]]

array_6 = np.array(Table_list_6layer)
array_11 = np.array(Table_list_11layer)
array_17 = np.array(Table_list_17layer)

# %%
x2 = np.arange(len([2,4,10,100]))
plt.plot(x2, array_17[0:4,5],'-o', label = 'True LWR')
plt.plot(x2[1:], array_6[1:4,6],'-o', label = '6layer distance')
plt.plot(x2, array_11[0:4,6], '-o', label = '11layer distance')
plt.plot(x2, array_17[0:4,6], '-o', label = '17layer distance')

plt.xticks(x2, [2,4,10,100])
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=14)
plt.ylim(0.8,2.5)
plt.yscale('linear')
plt.xlabel('Poisson Noise (Electrons per pixel)', fontsize = 16)
plt.ylabel('LWR (nm)', fontsize = 16)
plt.show()

plt.plot(x2, array_17[4:8,5],'-o', label = 'True LWR')
plt.plot(x2[1:], array_6[5:8,6],'-o', label = '6layer distance')
plt.plot(x2, array_11[4:8,6], '-o', label = '11layer distance')
plt.plot(x2, array_17[4:8,6], '-o', label = '17layer distance')

plt.xticks(x2, [2,4,10,100])
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=14)
plt.ylim(0.8,2.5)
plt.yscale('linear')
plt.xlabel('Poisson Noise (Electrons per pixel)', fontsize = 16)
plt.ylabel('LWR (nm)', fontsize = 16)
plt.show()

plt.plot(x2, array_17[8:12,5],'-o', label = 'True LWR')
plt.plot(x2[1:], array_6[9:12,6],'-o', label = '6layer distance')
plt.plot(x2, array_11[8:12,6], '-o', label = '11layer distance')
plt.plot(x2, array_17[8:12,6], '-o', label = '17layer pred LWR')

plt.xticks(x2, [2,4,10,100])
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=14)
plt.ylim(0.8,2.5)
plt.yscale('linear')
plt.xlabel('Poisson Noise (Electrons per pixel)', fontsize = 16)
plt.ylabel('LWR (nm)', fontsize = 16)
plt.show()

# %%
x2 = np.arange(len([2,4,10,100]))
#plt.plot(x2, array_17[0:4,5],'-o', label = 'True LWR')
plt.plot(x2[1:], array_6[1:4,8],'-o', label = '6layer')
plt.plot(x2, array_11[0:4,8], '-o', label = '11layer')
plt.plot(x2, array_17[0:4,8], '-o', label = '17layer')

plt.xticks(x2, [2,4,10,100])
#plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=14)
plt.legend(fontsize=14)
plt.ylim(0,1750)
plt.yscale('linear')
plt.xlabel('Poisson Noise (Electrons per pixel)', fontsize = 16)
plt.ylabel('Euclidean distance (nm^3)', fontsize = 16)
plt.show()

#plt.plot(x2, array_17[4:8,5],'-o', label = 'True LWR')
plt.plot(x2[1:], array_6[5:8,8],'-o', label = '6layer')
plt.plot(x2, array_11[4:8,8], '-o', label = '11layer')
plt.plot(x2, array_17[4:8,8], '-o', label = '17layer')

plt.xticks(x2, [2,4,10,100])
#plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=14)
plt.legend(fontsize=14)
plt.ylim(0,1750)
plt.yscale('linear')
plt.xlabel('Poisson Noise (Electrons per pixel)', fontsize = 16)
plt.ylabel('Euclidean distance (nm^3)', fontsize = 16)
plt.show()

#plt.plot(x2, array_17[8:12,5],'-o', label = 'True LWR')
plt.plot(x2[1:], array_6[9:12,8],'-o', label = '6layer')
plt.plot(x2, array_11[8:12,8], '-o', label = '11layer')
plt.plot(x2, array_17[8:12,8], '-o', label = '17layer')

plt.xticks(x2, [2,4,10,100])
#plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=14)
plt.legend(fontsize=14)
plt.ylim(0,1750)
plt.yscale('linear')
plt.xlabel('Poisson Noise (Electrons per pixel)', fontsize = 16)
plt.ylabel('Euclidean distance (nm^3)', fontsize = 16)
plt.show()
